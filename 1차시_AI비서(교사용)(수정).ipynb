# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">인공지능 윤리</div>
#     <div style="font-weight: bold; font-size: 20px">[01] 인공지능과 프라이버시 보호</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <활동 목표>
#         <br>생성형 인공지능의 사생활 침해 위험성을 인식하고, 프라이버시를 보호하는 프로그램을 구현한다.<br><br>
#         [활동 1] 파이썬 기본 기능 익히기<br>
#         [활동 2] 간단한 인공지능 스피커 구현하기<br>
#         [활동 3] 코드를 수정해 개인정보 보호 기능 추가하기<br>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;"><h2 style='font-weight: bold'>0. 생성형 인공지능의 사생활 침해</h2></div>

# %% [markdown]
# 생성형 인공지능은 우리의 사생활을 어떻게 위협하는 걸까요? 우리는 어떻게 인공지능으로부터 우리의 소중한 사생활을 지킬 수 있을까요?

# %% [markdown]
# ![image-2.png](attachment:image-2.png)<br>
# <div><a href='https://youtu.be/kHZM5Dgyjwk?si=DqK0t5HFNGdAJfKb' target=_new>사생활 침해 가능성 1</a></div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 1</div>
#     <br>
# 1. 영상은 어떤 내용이었나요? (7:20~8:03)<br>
#     2. 게임 속 NPC와 사적인 대화를 주고받을 수 있다면 어떨까요? <br>
#     3. 게임에서 대화한 내용을 누군가 듣고 있다면 어떨까요?
#     <br>
# </div>

# %%
👉

# %% [markdown]
# ![image-3.png](attachment:image-3.png)<br>
# <div><a href='https://youtu.be/DA4Zh-wCszs?si=kEq9BE0W9QUqaNdA' target=_new>사생활 침해 가능성 2</a></div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 2</div>
#     <br>
# 1. 영상은 어떤 내용이었나요?<br>
#     2. SNS의 맞춤형 광고를 보고 물건을 구매해본 적이 있나요?<br>
#     3. 광고를 제공하기 위해 우리의 어떤 정보를 활용할까요?<br>
# </div>

# %%
 👉

# %% [markdown]
# ![%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C.png](attachment:%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C.png)

# %% [markdown]
# 여러분은 여러분의 정보가 이렇게 회사에 노출되고 있다는 사실을 알고 있었나요? 노출되어도 괜찮나요? 찜찜한 기분이 들 수도 있습니다.
#
# 왜냐하면 내가 이용한 콘텐츠의 내용은 모두 나의 사생활이기 때문이죠. 영어로 프라이버시라고 합니다.

# %% [markdown]
# ![%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C%20%281%29.png](attachment:%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C%20%281%29.png)

# %% [markdown]
# 사람이 중심이 되는 윤리 기준에서는 프라이버시 보호를 다음과 같이 정의하고 있습니다.
#
# 첫째, 인공지능을 개발하고 활용하는 전 과정에서 개인의 프라이버시, 즉 사생활을 보호해야 합니다.
#
# 둘째, 인공지능 전 생애주기에 걸쳐 개인 정보의 오용을 최소화하도록 노력해야 합니다.
#
# 즉, 인공지능을 학습시키고, 활용할 때 개인의 사적인 정보를 마구잡이로 활용하거나 노출되지 않도록 해야하는 것을 의미합니다. 인공지능은 어떻게 우리의 개인정보를 수집하고, 우리는 어떻게 인공지능으로부터 개인정보를 지킬 수 있을까요? AI 스피커를 만드는 다음 활동을 통해 생각해봅시다.

# %% [markdown]
# ## **<STEP 1> 기본 기능 익히기**

# %% [markdown]
# ## 1) 입출력

# %% [markdown]
# print() 명령어를 활용하여 원하는 문구를 출력할 수 있습니다.
#
# 하단의 셀을 실행시켜 문구를 출력해봅시다.

# %%
print('안녕하세요. 반갑습니다.')
# Out:
# 안녕하세요. 반갑습니다.

# %% [markdown]
# input() 명령어를 활용하여 사용자로부터 데이터를 입력받을 수도 있습니다.
#
# 하단의 셀을 실행시키고 인사말을 입력해봅시다.

# %%
a = input('문구를 입력해주세요.')
# Out:
# 문구를 입력해주세요. 안녕

# %% [markdown]
# 위에서 a 변수에 입력받은 문구를 출력하는 코드를 작성해봅시다.
#
# 이때, 변수에 저장된 데이터를 출력하는 것이므로 ''(따옴표)를 붙이지 않도록 주의합니다.

# %%
print(a)
# Out:
# 안녕

# %% [markdown]
# ## 2) 조건문

# %% [markdown]
# 입력된 데이터에 따라 다르게 출력되도록 구현할 수 있습니다.
#
# 다음 if 조건문을 실행해봅시다.

# %%
if '안녕' in a:
    print('안녕하세요.')
else:
    print('다시 입력해주세요.')
# Out:
# 안녕하세요.

# %% [markdown]
# 여러 조건을 동시에 만족하는 경우를 검사하는 코드도 작성할 수 있습니다.
#
# and 또는 or 를 사용해 조건을 작성해봅시다.

# %%
if '안녕' in a and '하세요' in a:
    print('안녕하세요.')
else:
    print('안녕.')
# Out:
# 안녕.

# %% [markdown]
# ## 3) 음성 인식

# %% [markdown]
# speech_recognition 모듈을 사용해 음성을 입력할 수 있습니다.
#
# (클로바 노트 음성 파일 준비해두기)

# %%
# !pip install SpeechRecognition
# Out:
# ...
#      --------------------------------------- 32.8/32.8 MB 28.5 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as sr              # 음성 인식 관련 명령어가 담긴 모듈

chat = 'test.wav'                            # 음성 파일 경로 입력
recognizer = sr.Recognizer()                 # 음성 인식 객체 생성
file_path = chat # 음성 파일 경로
with sr.AudioFile(file_path) as source:
    audio = recognizer.record(source)        

print(audio)                                 # 음성 소스 파일 녹음 후 AudioData 객체 반환

# %%
text = recognizer.recognize_google(audio, language='ko-KR')
print(text)
# Out:
# 안녕하세요

# %% [markdown]
# ## **<STEP 2> 음성 파일 불러오기**

# %% [markdown]
# 1. 클로바 노트에서 음성을 녹음해봅시다.

# %% [markdown]
# 2. wav 파일 변환 사이트를 활용해 녹음된 음성 파일의 형식을 wav로 변환합니다.

# %% [markdown]
# 3. 좌측 폴더의 '+' 버튼을 눌러, wav 파일을 업로드합니다.

# %% [markdown]
# 4. wav 파일의 이름을 나중에 봐도 알아볼 수 있게 적절한 이름으로 수정합니다.

# %% [markdown]
# 5. 경로를 파일 이름으로 수정하고 다시 음성 인식 코드를 실행해봅시다.

# %%
import speech_recognition as sr              # 음성 인식 관련 명령어가 담긴 모듈

# 빈칸 # chat = 'test.wav'                            # 음성 파일 경로 입력
recognizer = sr.Recognizer()                 # 음성 인식 객체 생성
file_path = chat # 음성 파일 경로
with sr.AudioFile(file_path) as source:
    audio = recognizer.record(source)        

text = recognizer.recognize_google(audio, language='ko-KR')
print(text)

# %% [markdown]
# ## **<STEP 3> 챗봇 구현하기**

# %% [markdown]
# **[1단계] 챗봇 인트로 작성하기**
#
# 간단한 인사말과 챗봇의 기능을 소개하는 인트로를 작성해봅시다.

# %%
print('무엇을 도와드릴까요?')
print('사용 가능한 기능: 노래 추천 / 메뉴 추천 / 옷 추천') # 학습자가 기능 추가하기

# %% [markdown]
# **[2단계] 음성 파일 입력받기**
#
# 챗봇에게 질문을 입력하는 코드를 작성해봅시다.

# %%
chat = input('음성 파일의 이름을 입력해주세요. 종료를 원하시면 0을 입력해주세요.') # 입력받는 명령어

# %% [markdown]
# **[3단계] 음성 인식하기**
#
# 입력받은 음성 파일의 내용을 인식하고, 텍스트로 변환해봅시다.

# %%
import speech_recognition as sr              # 음성 인식 관련 명령어가 담긴 모듈

# wav 파일을 로드합니다.
recognizer = sr.Recognizer()                 # 음성 인식 객체 생성
file_path = chat # 음성 파일 경로
with sr.AudioFile(file_path) as source:
    audio = recognizer.record(source)        # 음성 소스 파일 녹음 후 AudioData 객체 반환

    
text = recognizer.recognize_google(audio, language='ko-KR') # 음성 파일을 텍스트로 변환
print(text)                                  # 텍스트를 출력

# %% [markdown]
# **[4단계] 챗봇 답변 작성하기**
#
# 입력받은 내용에서 키워드를 추출하고, 질문에 대한 답변을 if문을 활용해 작서해봅시다.

# %%
if '안녕' in text:
    print('AI: 안녕하세요.')
elif '반갑' in text:
    print('AI: 반가워요.')
elif '음악' in text and '추천' in text:
    print('신나는 아이돌 음악을 추천해요.')
else:
     print('다시 입력해주세요.')

# %% [markdown]
# **[5단계] 개인정보 보호하기**
#
# 입력받은 내용 중 개인정보가 포함되어있는지 검사하고, 포함되어있다면 답변을 생략하는 코드를 추가로 작성해봅시다.

# %%
if '이름' in text: #챗봇 코드의 어느 부분에 들어가야 할까? 음성 인식 직후 -> 개인 정보가 입력되면 바로 보호하기 위한 목적으로
    print('AI: 민감한 정보는 말할 수 없습니다.')

# %% [markdown]
# 1. 내가 질문하지 않았는데도 인공지능 챗봇 또는 인공지능 스피커가 내 일상을 엿듣고, 훔쳐보고 있다면 어떻게 될까요?
